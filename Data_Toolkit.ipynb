# %% [markdown]
# # Data Toolkit
# # Assignment Theroy Questions

# %% [markdown]
# 1. what is numpy and  why is it widely used in python?
#
# -> Numpy (Numerical python) is a python library used for numerical and scientific computing it provides support for array, matrices, and many mathematical function its fast and efficient, markting it ideal for handling large datasets.
#
#
#
# 2. How does broadcasting work in numpy?
#
# -> Broadcasting allows numpy to perfrom operations on array of differnt shapes it stretches the smaller array across the large one without copying data, enabling efficient computation.
#
#
#
# 3. What is a pandas DataFrame?
#
# -> DataFrame is a 2- dimesional, labeled data structure in pandas it's like a table in a database or an Excel spreadsheet with rows and columns.
#
#
#
# 4. Explain the use of the groupby()method in pandas?
#
# -> group()is used to split data into groups based on some criteria, apply a function(like mean or sum), and then combine the result.it's useful for aggregation and analysis.
#
#
#
# 5. Why is seabron perferred for statistical visualizations?
#
# -> Seabron is bulit on top of matplotlib and is easier to use for statistiacal plots. it provides attractive default style and makes complex visualization like heatmaps and violin plots simple to create.
#
#
#
# 6. What are the differnces between numpy array and python
#    lists?
#
# -> numpy array are more compact and faster.
#    they support element-wise operations and brocasting.
#    lists are more flexible but not optimized for numerical operations.
#
#
#
# 7. What is a heatmap, and when should it be used?
#
# -> A heatmap is a data visualization that uses color to represent values in a matrix. it's useful for showing correlation,patterns,or missing data.
#
#
#
# 8. What does the term " vectorized operation" mean in
#    numpy?
#
# -> it refers to operations applied to entire array without writting loop it's faster and more efficient than looping through individual elements.
#
#
#
# 9. How does matplottlib differ from plotly?
#
# -> Matplotlib is static and more customizable but complex.
#    plotly is interactive and easier for building dynamic charts, easpecially in dashboards.
#
#
#
# 10. What is the significance of hierarchical index in pandas?
#
# -> Hierarchical indexing(Multiindex) allows mutiple level of indexing.it's helpful for working with higher-dimensional data in a 2D structure.
#
#
#
# 11. What is the role of seabrons's pairplot()function?
#
# -> pairplot()plots pairwise relationships in a datasets it's useful for exploring distributions and relationships betteem features.
#
#
#
# 12. What is the purpose of the describe() function in panads?
#
# -> describe() provides summary statistics(mean,std,min,max,etc.) for numerical columns in a DataFrame.
#
#
#
# 13. Why is handling missing lead to incorrect analysis or errors Handling it properly ensure data integrity and accurate results.
#
#
#
# 14. What are the benefits of using plotly for data visualization?
#
# -> Interactive and visually appealing plots.
#    Easy integration with web applications.
#    Support for 3D plots and dashboards.
#
#
#
# 15. How does numpy handle  multidimensional arrays?
#
# -> numpy uses ndarray objects, which can be muti-dimensional Example: 2D matrices or 3D Tensors operations can be applied across dimensions efficiently.
#
#
#
# 16. What is the role of Boken in data visualization?
#
# -> Bokeh is used for interactive visualizations in web browsers it supports real-time streaming and dynamic updates.
#
#
#
# 17. Explain the difference between apply() and map() in pandas.
#
# -> map(): Used with Series(single column) to apply a function elements - wise .good for simple transformations.
#
# apply(): Can be used with both series and DataFrams. More verstatile-can apply functions along an axis.
#
#
#
# 18. What are some advanced features of numpy?
#
# -> Broadcasting
#    Vectorized operations
#    Marsked arrays
#    Linear algebra(numpy.linalg)
#    Fourier transfroms
#    Random number generation(numpy.random)
#    Memory-effcient slicing and views
#
#
#
# 19. How does pandas simplify time series analysis?
#
# -> Built-in Datertimeindex
#    Function like.resample(), shift(), rolling()
#    Easy handling of missing dates
#    Powerful time-based indexing and slicing
#    Built-in plotting for time series
#
#
#
# 20. What is the role of a piivot table in pandas?
#
# -> A pivot table summarizes data by aggregating it based on one or more keys.it helps in quick data analysis and restructing without changing the orignal data.
#
#
#
# 21. Why is numpy's array slicing faster than python's list
# slicing?
#
# -> numpy uses contiguous memory blocks and C-optimized code under  the hood.
#
# Operation are done at the C-level, not with python loops
#
# it avoids type-checking overhead that python lists have
#
#
#
# 22. What are some  common use cases for Seaborn?
#
# -> Creating statistical plots like:
#    Heatmaps
#    Box plots
#    Violin plots
#    Distribution plot
#    pair plots
# Visualizing correlations and relationships bettween feature
# Enhancing Matplotlib with better themes and color patettes.

# %% [markdown]
# # Practical Questions

# %%
# 1.
import numpy as np
arr = np.array([[1, 2, 3,], [4, 5, 6]])
row_sums = arr.sum(axis = 1)
print(row_sums)
# Out:
# [ 6 15]

# %%
# 2.
import pandas as pd
df = pd.DataFrame({'A':[1, 2, 3],'B':[4, 5, 6]})
mean_B = df['B'].mean()
print(mean_B)
# Out:
# 5.0

# %%
# 3.
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [4, 5, 6]
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y- axis')
plt.title('scatter plot')
plt.show()

# %%
# 4.
import seaborn as sns
import pandas as pd

df = pd.DataFrame({
    'A':[1, 2, 3, 4],
    'B':[4, 5, 6, 1]
})
corr = df.corr()
sns.heatmap(corr,annot = True)
plt.show()

# %%
# 5.
import plotly.express as px
import pandas as pd

df = pd.DataFrame({'item':["A", "B", "C"],'Count': [10, 20, 30]})
fig = px.bar(df, x = 'item', y = 'Count', title = 'Bar plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 6.
df = pd.DataFrame({'A': [1, 2, 3]})
df['B'] = df['A'] * 2
print(df)
# Out:
#    A  B
# 0  1  2
# 1  2  4
# 2  3  6

# %%
# 7.
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result = a * b
print(result)
# Out:
# [ 4 10 18]

# %%
# 8.
x = [1, 2, 3]
y1 = [2, 4, 6]
y2 = [1, 3, 5]
plt.plot(x, y1, label = 'line 1')
plt.plot(x, y2 , label = 'line 2')
plt .legend()
plt.show()

# %%
# 9.
df = pd.DataFrame({'A': [10, 20, 30]})
filtered = df[df['A']> 15]
print(filtered)
# Out:
#     A
# 1  20
# 2  30

# %%
# 10.
sns.histplot(df['A'], bins = 5)
plt.title('Histogram')
plt.show()

# %%
# 11.
a = np.array([[1,2],[3, 4]])
b = np.array([[5, 6],[7, 8]])
product = np.dot(a, b)
print(product)
# Out:
# [[19 22]
#  [43 50]]
# [[19 22]
#  [43 50]]

# %%
# 12.
from goole.colab import files uploaaded = file.uploaaded

import pandas as pd
df = pd.read_csv('your_actual_file_name.csv')
print(df.head())
df = pd.read_csv('data.csv')
# Out:
#   File "<ipython-input-23-4b4710fffcba>", line 2
#     from goole.colab import files uploaaded = file.uploaaded
#                                   ^
# SyntaxError: invalid syntax

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Scatter3d(
    x=[1, 2, 3],
    y=[4, 5, 6],
    z =[7, 8, 9],
    model = 'markers',
    marker=dict(size = 5)
)])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e515deae3b3f> in <cell line: 0>()
#       1 import plotly.graph_objects as go
# ----> 2 fig = go.Figure(data=[go.Scatter3d(
#       3     x=[1, 2, 3],
#       4     y=[4, 5, 6],
#       5     z =[7, 8, 9],
#
# ...
